# %%
pip install fastapi uvicorn
# Out:
# ...
#
#    ---------- ----------------------------- 1/4 [uvicorn]
#    ---------- ----------------------------- 1/4 [uvicorn]
#    ---------- ----------------------------- 1/4 [uvicorn]
#    ---------- ----------------------------- 1/4 [uvicorn]
#    ---------- ----------------------------- 1/4 [uvicorn]
#    ---------- ----------------------------- 1/4 [uvicorn]
#    ---------- ----------------------------- 1/4 [uvicorn]
#    ---------- ----------------------------- 1/4 [uvicorn]
#    -------------------- ------------------- 2/4 [starlette]
#    -------------------- ------------------- 2/4 [starlette]
#    -------------------- ------------------- 2/4 [starlette]
#    -------------------- ------------------- 2/4 [starlette]
#    -------------------- ------------------- 2/4 [starlette]
#    -------------------- ------------------- 2/4 [starlette]
#    -------------------- ------------------- 2/4 [starlette]
#    -------------------- ------------------- 2/4 [starlette]
# ...

# %% [markdown]
# Downloaded the fast API and uvicorn for the next step of process.
